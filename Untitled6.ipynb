# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the sports data
sports_data = pd.read_csv('/content/fifa_eda_stats.csv')
# Assuming you have columns 'Team' and 'Wins' in your dataset

plt.bar(sports_data['Weak Foot'], sports_data['Skill Moves'], color=['blue', 'red'])
plt.title("PLAYERS MOVES")
plt.xlabel("Weak Foot")
plt.ylabel("Skill Moves")
plt.show()
