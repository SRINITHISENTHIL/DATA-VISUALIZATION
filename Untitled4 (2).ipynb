# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataset
data = pd.read_csv('/content/Customer_DF (1).csv')

# Analyze Most Popular Products/Categories

# Bar Chart for Most Popular Products

plt.bar(data['No_Orders'],data['No_Payments'])
plt.title("Most Popular Products")
plt.xlabel("ORDERS")
plt.ylabel("PAYMENYS")
plt.xticks(rotation=45)
plt.show()

# Pie Chart for Click Distribution by Category
#category_clicks = data.groupby('category')['clicks'].sum()
#plt.figure(figsize=(8, 8)
#plt.pie(category_clicks, labels=category_clicks.index, autopct='%1.1f%%')
#plt.title("Click Distribution by Category")
#plt.show()
